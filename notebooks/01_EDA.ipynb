# %% [markdown]
# ## **WORKSHOP 003 - NOTEBOOK #1: Exploratory Data Analysis (EDA)**

# %% [markdown]
# ### **Setting Environment**

# %%
import os 
print(os.getcwd())

try:
    os.chdir("../../workshop-003")

except FileNotFoundError:
    print("""
        FileNotFoundError - The directory may not exist or you might not be in the specified path.
        If this has already worked, do not run this block again, as the current directory is already set to workshop-003.
        """)
    
print(os.getcwd())
# Out:
# d:\U\FIFTH SEMESTER\ETL\workshop-003\notebooks
# d:\U\FIFTH SEMESTER\ETL\workshop-003

# %% [markdown]
# ### **Importing modules and libraries**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import country_converter as coco
import plotly.express as px
import seaborn as sns

from utilities.analytics import *

# %% [markdown]
# ### **Read Data**

# %% [markdown]
# #### **Year 2015**

# %%
df_2015 = pd.read_csv("./data/raw/2015.csv")
df_2015.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
df_2015.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %% [markdown]
# #### **Year 2016**

# %%
df_2016 = pd.read_csv("./data/raw/2016.csv")
df_2016.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0      Denmark  Western Europe               1            7.526
# 1  Switzerland  Western Europe               2            7.509
# 2      Iceland  Western Europe               3            7.501
# 3       Norway  Western Europe               4            7.498
# 4      Finland  Western Europe               5            7.413
#
#    Lower Confidence Interval  Upper Confidence Interval  \
# 0                      7.460                      7.592
# 1                      7.428                      7.590
# 2                      7.333                      7.669
# 3                      7.421                      7.575
# 4                      7.351                      7.475
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.44178  1.16374                   0.79504  0.57941
# 1                   1.52733  1.14524                   0.86303  0.58557
# ...

# %%
df_2016.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 13 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        157 non-null    object
#  1   Region                         157 non-null    object
#  2   Happiness Rank                 157 non-null    int64
#  3   Happiness Score                157 non-null    float64
#  4   Lower Confidence Interval      157 non-null    float64
#  5   Upper Confidence Interval      157 non-null    float64
#  6   Economy (GDP per Capita)       157 non-null    float64
#  7   Family                         157 non-null    float64
#  8   Health (Life Expectancy)       157 non-null    float64
#  9   Freedom                        157 non-null    float64
#  10  Trust (Government Corruption)  157 non-null    float64
#  11  Generosity                     157 non-null    float64
# ...

# %% [markdown]
# #### **Year 2017**

# %%
df_2017 = pd.read_csv("./data/raw/2017.csv")
df_2017.head()
# Out:
#        Country  Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# 0       Norway               1            7.537      7.594445     7.479556
# 1      Denmark               2            7.522      7.581728     7.462272
# 2      Iceland               3            7.504      7.622030     7.385970
# 3  Switzerland               4            7.494      7.561772     7.426227
# 4      Finland               5            7.469      7.527542     7.410458
#
#    Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.   Freedom  \
# 0                  1.616463  1.533524                  0.796667  0.635423
# 1                  1.482383  1.551122                  0.792566  0.626007
# 2                  1.480633  1.610574                  0.833552  0.627163
# 3                  1.564980  1.516912                  0.858131  0.620071
# 4                  1.443572  1.540247                  0.809158  0.617951
#
#    Generosity  Trust..Government.Corruption.  Dystopia.Residual
# ...

# %%
df_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 155 entries, 0 to 154
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        155 non-null    object
#  1   Happiness.Rank                 155 non-null    int64
#  2   Happiness.Score                155 non-null    float64
#  3   Whisker.high                   155 non-null    float64
#  4   Whisker.low                    155 non-null    float64
#  5   Economy..GDP.per.Capita.       155 non-null    float64
#  6   Family                         155 non-null    float64
#  7   Health..Life.Expectancy.       155 non-null    float64
#  8   Freedom                        155 non-null    float64
#  9   Generosity                     155 non-null    float64
#  10  Trust..Government.Corruption.  155 non-null    float64
#  11  Dystopia.Residual              155 non-null    float64
# ...

# %% [markdown]
# #### **Year 2018**

# %%
df_2018 = pd.read_csv("./data/raw/2018.csv")
df_2018.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.632           1.305           1.592
# 1             2            Norway  7.594           1.456           1.582
# 2             3           Denmark  7.555           1.351           1.590
# 3             4           Iceland  7.495           1.343           1.644
# 4             5       Switzerland  7.487           1.420           1.549
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.874                         0.681       0.202
# 1                    0.861                         0.686       0.286
# 2                    0.868                         0.683       0.284
# 3                    0.914                         0.677       0.353
# 4                    0.927                         0.660       0.256
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.340
# ...

# %%
df_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Overall rank                  156 non-null    int64
#  1   Country or region             156 non-null    object
#  2   Score                         156 non-null    float64
#  3   GDP per capita                156 non-null    float64
#  4   Social support                156 non-null    float64
#  5   Healthy life expectancy       156 non-null    float64
#  6   Freedom to make life choices  156 non-null    float64
#  7   Generosity                    156 non-null    float64
#  8   Perceptions of corruption     155 non-null    float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 11.1+ KB

# %% [markdown]
# #### **Year 2019**

# %%
df_2019 = pd.read_csv("./data/raw/2019.csv")
df_2019.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# ...

# %%
df_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Overall rank                  156 non-null    int64
#  1   Country or region             156 non-null    object
#  2   Score                         156 non-null    float64
#  3   GDP per capita                156 non-null    float64
#  4   Social support                156 non-null    float64
#  5   Healthy life expectancy       156 non-null    float64
#  6   Freedom to make life choices  156 non-null    float64
#  7   Generosity                    156 non-null    float64
#  8   Perceptions of corruption     156 non-null    float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 11.1+ KB

# %% [markdown]
# ### **Data Comparison**

# %%
happiness_dfs = {
    "2015": df_2015,
    "2016": df_2016,
    "2017": df_2017,
    "2018": df_2018,
    "2019": df_2019
}

# %%
brief = df_brief(happiness_dfs)
brief
# Out:
#    Year  Number of rows  Number of columns  Total missing values  \
# 0  2015             158                 12                     0
# 1  2016             157                 13                     0
# 2  2017             155                 12                     0
# 3  2018             156                  9                     1
# 4  2019             156                  9                     0
#
#    Total duplicate entries
# 0                        0
# 1                        0
# 2                        0
# 3                        0
# 4                        0

# %%
comparison_df = compare_names_bool(happiness_dfs)
comparison_df
# Out:
#                                 2015   2016   2017   2018   2019
# Column Name
# Economy (GDP per Capita)        True   True  False  False  False
# Whisker.low                    False  False   True  False  False
# Country or region              False  False  False   True   True
# Dystopia.Residual              False  False   True  False  False
# Family                          True   True   True  False  False
# Freedom to make life choices   False  False  False   True   True
# Region                          True   True  False  False  False
# Whisker.high                   False  False   True  False  False
# Upper Confidence Interval      False   True  False  False  False
# Standard Error                  True  False  False  False  False
# Trust (Government Corruption)   True   True  False  False  False
# GDP per capita                 False  False  False   True   True
# Country                         True   True   True  False  False
# ...

# %% [markdown]
# ### **Data Preprocessing**

# %% [markdown]
# #### **Column Name Normalisation**

# %%
column_mapping = {    
    # ountry
    'Country': 'country',
    'Country or region': 'country',
    
    #Happiness Score
    'Happiness Score': 'happiness_score',
    'Happiness.Score': 'happiness_score',
    'Score': 'happiness_score',
    
    #Happiness Rank
    'Happiness Rank': 'happiness_rank',
    'Happiness.Rank': 'happiness_rank',
    'Overall rank': 'happiness_rank',
    
    #Economy (GDP per Capita)
    'Economy (GDP per Capita)': 'gdp_per_capita',
    'Economy..GDP.per.Capita.': 'gdp_per_capita',
    'GDP per capita': 'gdp_per_capita',
    
    #Health (Life Expectancy)
    'Health (Life Expectancy)': 'health_life_expectancy',
    'Health..Life.Expectancy.': 'health_life_expectancy',
    'Healthy life expectancy': 'health_life_expectancy',
    
    #Social Support
    'Family': 'social_support',
    'Social support': 'social_support',
    
    #Freedom
    'Freedom': 'freedom',
    'Freedom to make life choices': 'freedom',
    
    #Perceptions of Corruption
    'Trust (Government Corruption)': 'government_corruption',
    'Trust..Government.Corruption.': 'government_corruption',
    'Perceptions of corruption': 'government_corruption',
    
    #Generosity
    'Generosity': 'generosity',
    
    #Dystopia Residual
    'Dystopia Residual': 'dystopia_residual',
    'Dystopia.Residual': 'dystopia_residual',
}

# %%
normalised_dfs = {}

for year, df in happiness_dfs.items():
    df = df.rename(columns=column_mapping)
    normalised_dfs[year] = df

# %%
normalised_dfs['2016'].head()
# Out:
#        country          Region  happiness_rank  happiness_score  \
# 0      Denmark  Western Europe               1            7.526
# 1  Switzerland  Western Europe               2            7.509
# 2      Iceland  Western Europe               3            7.501
# 3       Norway  Western Europe               4            7.498
# 4      Finland  Western Europe               5            7.413
#
#    Lower Confidence Interval  Upper Confidence Interval  gdp_per_capita  \
# 0                      7.460                      7.592         1.44178
# 1                      7.428                      7.590         1.52733
# 2                      7.333                      7.669         1.42666
# 3                      7.421                      7.575         1.57744
# 4                      7.351                      7.475         1.40598
#
#    social_support  health_life_expectancy  freedom  government_corruption  \
# ...

# %% [markdown]
# #### **_'Year'_ Column**

# %%
year_happiness_dfs = {}

# %%
for year, df in normalised_dfs.items():
    df['year'] = year
    year_happiness_dfs[year] = df

# %%
year_happiness_dfs['2017'].head()
# Out:
#        country  happiness_rank  happiness_score  Whisker.high  Whisker.low  \
# 0       Norway               1            7.537      7.594445     7.479556
# 1      Denmark               2            7.522      7.581728     7.462272
# 2      Iceland               3            7.504      7.622030     7.385970
# 3  Switzerland               4            7.494      7.561772     7.426227
# 4      Finland               5            7.469      7.527542     7.410458
#
#    gdp_per_capita  social_support  health_life_expectancy   freedom  \
# 0        1.616463        1.533524                0.796667  0.635423
# 1        1.482383        1.551122                0.792566  0.626007
# 2        1.480633        1.610574                0.833552  0.627163
# 3        1.564980        1.516912                0.858131  0.620071
# 4        1.443572        1.540247                0.809158  0.617951
#
#    generosity  government_corruption  dystopia_residual  year
# ...

# %% [markdown]
# #### **_'Continent'_ Column**

# %%
cc = coco.CountryConverter()

# %%
for year, df in year_happiness_dfs.items():
    year_happiness_dfs[year]["continent"] = cc.convert(names=df["country"].tolist(), to="continent")
    
    continent_mapping = {
        "Argentina": "South America",
        "Belize": "Central America",
        "Bolivia": "South America",
        "Brazil": "South America",
        "Canada": "North America",
        "Chile": "South America",
        "Colombia": "South America",
        "Costa Rica": "Central America",
        "Dominican Republic": "Central America",
        "Ecuador": "South America",
        "El Salvador": "Central America",
        "Guatemala": "Central America",
        "Honduras": "Central America",
        "Haiti": "Central America",
        "Jamaica": "Central America",
        "Mexico": "North America",
        "Panama": "Central America",
        "Paraguay": "South America",
        "Peru": "South America",
        "Puerto Rico": "Central America",
        "Trinidad and Tobago": "South America",
        "Trinidad & Tobago": "South America",
        "United States": "North America",
        "Uruguay": "South America",
        "Venezuela": "South America"
    }
    year_happiness_dfs[year]["continent"] = year_happiness_dfs[year]["country"].map(continent_mapping).fillna(year_happiness_dfs[year]["continent"])

year_happiness_dfs['2017'][["continent", "country"]].head()
# Out:
#   continent      country
# 0    Europe       Norway
# 1    Europe      Denmark
# 2    Europe      Iceland
# 3    Europe  Switzerland
# 4    Europe      Finland

# %% [markdown]
# #### **Dataframe Concatenation**

# %%
comparison_year_df = compare_names_bool(year_happiness_dfs)
comparison_year_df
# Out:
#                             2015   2016   2017   2018   2019
# Column Name
# Standard Error              True  False  False  False  False
# generosity                  True   True   True   True   True
# Whisker.low                False  False   True  False  False
# Whisker.high               False  False   True  False  False
# country                     True   True   True   True   True
# happiness_score             True   True   True   True   True
# gdp_per_capita              True   True   True   True   True
# health_life_expectancy      True   True   True   True   True
# Lower Confidence Interval  False   True  False  False  False
# continent                   True   True   True   True   True
# Region                      True   True  False  False  False
# happiness_rank              True   True   True   True   True
# government_corruption       True   True   True   True   True
# dystopia_residual           True   True   True  False  False
# ...

# %%
columns_common = list(set.intersection(*(set(df.columns) for df in year_happiness_dfs.values())))

# %%
filtered_dfs = [df[columns_common] for df in year_happiness_dfs.values()]

# %%
df = pd.concat(filtered_dfs, ignore_index=True)

df.head()
# Out:
#    generosity      country  gdp_per_capita  happiness_score  \
# 0     0.29678  Switzerland         1.39651            7.587
# 1     0.43630      Iceland         1.30232            7.561
# 2     0.34139      Denmark         1.32548            7.527
# 3     0.34699       Norway         1.45900            7.522
# 4     0.45811       Canada         1.32629            7.427
#
#    health_life_expectancy      continent  happiness_rank  \
# 0                 0.94143         Europe               1
# 1                 0.94784         Europe               2
# 2                 0.87464         Europe               3
# 3                 0.88521         Europe               4
# 4                 0.90563  North America               5
#
#    government_corruption  year  freedom  social_support
# 0                0.41978  2015  0.66557         1.34951
# 1                0.14145  2015  0.62877         1.40223
# 2                0.48357  2015  0.64938         1.36058
# ...

# %% [markdown]
# #### **NA & 0 Values**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 782 entries, 0 to 781
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   generosity              782 non-null    float64
#  1   country                 782 non-null    object
#  2   gdp_per_capita          782 non-null    float64
#  3   happiness_score         782 non-null    float64
#  4   health_life_expectancy  782 non-null    float64
#  5   continent               782 non-null    object
#  6   happiness_rank          782 non-null    int64
#  7   government_corruption   781 non-null    float64
#  8   year                    782 non-null    object
#  9   freedom                 782 non-null    float64
#  10  social_support          782 non-null    float64
# dtypes: float64(7), int64(1), object(3)
# memory usage: 67.3+ KB

# %%
df[df['government_corruption'].isna()]
# Out:
#      generosity               country  gdp_per_capita  happiness_score  \
# 489       0.186  United Arab Emirates           2.096            6.774
#
#      health_life_expectancy continent  happiness_rank  government_corruption  \
# 489                    0.67      Asia              20                    NaN
#
#      year  freedom  social_support
# 489  2018    0.284           0.776

# %%
df.describe()
# Out:
#        generosity  gdp_per_capita  happiness_score  health_life_expectancy  \
# count  782.000000      782.000000       782.000000              782.000000
# mean     0.218576        0.916047         5.379018                0.612416
# std      0.122321        0.407340         1.127456                0.248309
# min      0.000000        0.000000         2.693000                0.000000
# 25%      0.130000        0.606500         4.509750                0.440183
# 50%      0.201982        0.982205         5.322000                0.647310
# 75%      0.278832        1.236187         6.189500                0.808000
# max      0.838075        2.096000         7.769000                1.141000
#
#        happiness_rank  government_corruption     freedom  social_support
# count      782.000000             781.000000  782.000000      782.000000
# mean        78.698210               0.125436    0.411091        1.078392
# std         45.182384               0.105816    0.152880        0.329548
# ...

# %%
df["government_corruption"] = (df["government_corruption"].fillna(df["government_corruption"].mean()))

df.query("country == 'United Arab Emirates' & year == '2018'")
# Out:
#      generosity               country  gdp_per_capita  happiness_score  \
# 489       0.186  United Arab Emirates           2.096            6.774
#
#      health_life_expectancy continent  happiness_rank  government_corruption  \
# 489                    0.67      Asia              20               0.125436
#
#      year  freedom  social_support
# 489  2018    0.284           0.776

# %%
df[df['government_corruption'].isna()]
# Out:
# Empty DataFrame
# Columns: [generosity, country, gdp_per_capita, happiness_score, health_life_expectancy, continent, happiness_rank, government_corruption, year, freedom, social_support]
# Index: []

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 782 entries, 0 to 781
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   generosity              782 non-null    float64
#  1   country                 782 non-null    object
#  2   gdp_per_capita          782 non-null    float64
#  3   happiness_score         782 non-null    float64
#  4   health_life_expectancy  782 non-null    float64
#  5   continent               782 non-null    object
#  6   happiness_rank          782 non-null    int64
#  7   government_corruption   782 non-null    float64
#  8   year                    782 non-null    object
#  9   freedom                 782 non-null    float64
#  10  social_support          782 non-null    float64
# dtypes: float64(7), int64(1), object(3)
# memory usage: 67.3+ KB

# %%
df[df.eq(0).any(axis=1)].head()
# Out:
#      generosity           country  gdp_per_capita  happiness_score  \
# 73      0.51535         Indonesia         0.82827            5.399
# 101     0.00000            Greece         1.15406            4.857
# 111     0.17922              Iraq         0.98549            4.677
# 119     0.24834  Congo (Kinshasa)         0.00000            4.517
# 122     0.21488      Sierra Leone         0.33024            4.507
#
#      health_life_expectancy continent  happiness_rank  government_corruption  \
# 73                  0.63793      Asia              74                0.00000
# 101                 0.88213    Europe             102                0.01397
# 111                 0.60237      Asia             112                0.13788
# 119                 0.09806    Africa             120                0.07625
# 122                 0.00000    Africa             123                0.08786
#
#      year  freedom  social_support
# 73   2015  0.46611         1.08708
# ...

# %% [markdown]
# #### **Column Organisation**

# %%
new_order = [
    'country',
    'continent',
    'year',
    'gdp_per_capita',
    'health_life_expectancy',
    'social_support',
    'freedom',
    'government_corruption',
    'generosity',
    'happiness_rank',
    'happiness_score'
]

df = df[new_order]
df.head()
# Out:
#        country      continent  year  gdp_per_capita  health_life_expectancy  \
# 0  Switzerland         Europe  2015         1.39651                 0.94143
# 1      Iceland         Europe  2015         1.30232                 0.94784
# 2      Denmark         Europe  2015         1.32548                 0.87464
# 3       Norway         Europe  2015         1.45900                 0.88521
# 4       Canada  North America  2015         1.32629                 0.90563
#
#    social_support  freedom  government_corruption  generosity  happiness_rank  \
# 0         1.34951  0.66557                0.41978     0.29678               1
# 1         1.40223  0.62877                0.14145     0.43630               2
# 2         1.36058  0.64938                0.48357     0.34139               3
# 3         1.33095  0.66973                0.36503     0.34699               4
# 4         1.32261  0.63297                0.32957     0.45811               5
#
#    happiness_score
# 0            7.587
# ...

# %% [markdown]
# ### **Data Comprehension and Analysis**

# %%
df.hist(figsize=(10, 8), edgecolor='black', color='#659B5E')
plt.show()

# %%
correlation_matrix_df = df.drop(["country", "continent"], axis=1)

correlation_matrix = correlation_matrix_df.corr()

plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap="twilight_shifted", fmt=".2f")
plt.title("Correlation Matrix")
plt.show()

# %%
avg_happiness_by_country = df.groupby("country")["happiness_score"].mean().sort_values(ascending=True).head(10)
avg_happiness_by_continent = df.groupby("continent")["happiness_score"].mean().sort_values(ascending=True).head(10)

fig, axes = plt.subplots(1, 2, figsize=(15, 6))

avg_happiness_by_country.plot(kind="barh", ax=axes[0], color="#8D99AE")
axes[0].set_title("Top 10 Countries by Average Happiness Score")
axes[0].set_xlabel("Average Happiness Score")
axes[0].set_ylabel("Country")

avg_happiness_by_continent.plot(kind="barh", ax=axes[1], color="#73628A")
axes[1].set_title("Top 10 Continents by Average Happiness Score")
axes[1].set_xlabel("Average Happiness Score")
axes[1].set_ylabel("Continent")


plt.tight_layout()
plt.show()

# %%
top_5_countries = df.groupby('country')['happiness_score'].mean().nlargest(5).index

df_top_5 = df[df['country'].isin(top_5_countries)].copy()

df_top_5['year'] = df_top_5['year'].astype(int)

plt.figure(figsize=(10, 6))

for country in top_5_countries:
    df_country = df_top_5[df_top_5['country'] == country]
    plt.plot(df_country['year'], df_country['happiness_score'], label=country)

plt.xlabel('Year')
plt.ylabel('Happiness Score')
plt.title('Trend in Happiness Scores Over Five Years for the Five Happiest Countries')
plt.legend()

plt.grid(False)
plt.show()

# %%
fig = px.choropleth(df, 
                    locations="country", 
                    locationmode="country names", 
                    color="happiness_score", 
                    hover_name="country", 
                    color_continuous_scale="Blues", 
                    title="Happiness Score per Country")

fig.show()

# %%
average_scores_by_year = df.groupby('year')['happiness_score'].mean().reset_index()

plt.figure(figsize=(10, 6))

bars = plt.bar(average_scores_by_year['year'], average_scores_by_year['happiness_score'], color='#FFC100')

plt.xlabel('Year')
plt.ylabel('Average Happiness Score')
plt.title('Average Happiness Score per Year')

for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval, round(yval, 2), va='bottom')

plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### **CSV Exportation**

# %%
df.to_csv("./data/processed/world_happiness_report.csv", index=False)
